# %% [markdown]
# ### **if elif else** - ***Task***

# %%
a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
c = int(input("Enter a number: "))

if a > b and a > c:
    print("A is bigger:", a)
elif b > a and b > c:
    print("B is bigger:", b)
else:
    print("C is bigger:", c)
# Out:
# C is bigger: 100

# %%
a = int(input("Enter a Number :"))
b = int(input("Enter a Number :"))
c = int(input("Enter a Number :"))

if a >= b and a >= c:
    if a == b == c:
        print("All numbers are equal:", a)
    elif a == b:
        print("A and B are equal and biggest:", a)
    elif a == c:
        print("A and C are equal and biggest:", a)
    else:
        print("A is bigger than B and C:", a)

elif b >= a and b >= c:
    if b == c:
        print("B and C are equal and biggest:", b)
    else:
        print("B is bigger than A and C:", b)

else:
    print("C is bigger than A and B:", c)
# Out:
# A and C are equal and biggest: 400

# %%
a = int (input("Enter the number:"))
b = int (input("Enter the number:"))
c = int (input("Enter the number:"))
if a <= b and a <= c:
    if  a == b ==c:
        print("All nubers are equal:",a)
    elif a==b:
        print("A and B are equal and smallest:",a)
    elif a==c:
        print("A and C are equal and smallest:",a)
    else:
        print("A is smallest than b and C:",a)
elif b <= a and b <= c:
    if b == c:
        print("B and C are equal and smallest:",b)
    else:
        print("B is smallest then A and C",b)
else:
    print("C is smaller then A and B",c)
# Out:
# A and B are equal and smallest: 54
