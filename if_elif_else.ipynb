# %% [markdown]
# ### **if else**

# %%
a = 500
if a>100:
    print(a,"is bigger then 100")
else:
    print(a,"is smaller then 100")
# Out:
# 500 is bigger then 100

# %%
a= 0
if a:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# ### **if elif else**

# %%
a = 200
if a<100:
    print(a,"is smaller then 100")
elif a == 100:
    print(a,"is equal to 100")
else:
    print(a,"is greater then 100")
# Out:
# 200 is greater then 100

# %%
a = 100
if a>100:
    print("a is bigger")
elif a == 50:
    print("a is 50")
elif a == 60:
    print("a is 60")
elif a == 100:
    print("a is 100")
else:
    print("a is smaller")
# Out:
# a is 100

# %% [markdown]
# ### **Nested if & else**

# %%
a= -500
if a>100:
    print("a is bigger")
    if a>500:
        print("a is biggest")
    else:
        print("a is between 100 to 999")
elif a<100:
    print("a is smaller")
    if a<0:
        print("a is negative")
    else:
        print("a is between 0 to -999")
# Out:
# a is smaller
# a is negative

# %% [markdown]
# ### **short hand if & else**

# %%
a = 10
b = 50
if a > b:print("a is bigger then b")
else:print("b is bigger then a")
# Out:
# b is bigger then a

# %%
a = int(input("Enter a Number :"))
b = int(input("Enter a Number :"))
if a>b:
    print(a,"a is bigger then b",b)
elif a == b:
    print(a,"a is equal to b",b)
else:
    print(a,"A is smaller then B",b)
# Out:
# 50 A is smaller then B 100
