# %% [markdown]
# ### ***Python practice***

# %%
# 1. Create a variable x with value 10 and a variable y with value 20. Print their sum.
x=10
y=20
z=x+y
print(z)
# Out:
# 30

# %%
# 2. Assign your name to a variable name and print "Hello, <name>".
name = "Bratheep"
print("Hello,",name)
# Out:
# hello, Bratheep

# %%
# 3. Swap two variables a = 5 and b = 10 without using a third variable.
a = 5 
b = 10
a,b = b,a
print("a =",a)
print("b =",b)
# Out:
# a = 10
# b = 5

# %%
# 4. Take user input for age and print "You are <age> years old".
age = input("Enter your age: ")
print("You are",age,"years old")
# Out:
# You are 22 years old

# %%
# 5. Write a Python program to check if a number is even or odd using the modulus operator.
num = int(input("Enter the number:"))
if num % 2==0:
    print ("Even")
else:
    print("Odd")
# Out:
# Even

# %%
# 6. If a = 15 and b = 4, find the sum, difference, product, division, and modulus.
a = 15
b = 4
print("Sum =",a + b)
print("Difference =",a - b)
print("Product =",a * b)
print("Division =",a / b)
print("Modulus =",a % b)
# Out:
# Sum = 19
# Difference = 11
# Product = 60
# Division = 3.75
# Modulus = 3

# %%
# 7. Write a Python program that checks if a number is positive, negative, or zero.
num = int(input("Enter the number: "))
if num > 0:
    print("Positive number")
elif num < 0:
    print("Negative number")
else:
    print("Zero")
# Out:
# Positive number
